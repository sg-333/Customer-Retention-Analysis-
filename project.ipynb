# %% [markdown]
# ### Data Collection and Exploration

# %% [markdown]
# ##### Dataset Loading:

# %%
# Importing all the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Import dataset from csv file
df = pd.read_csv('BankChurners.csv')
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
# First 5 rows
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
# Last 5 rows
df.tail()
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  \
# ...

# %% [markdown]
# ##### Initial Exploration:

# %% [markdown]
# Data Structure:

# %%
# Rows and columns in the dataset
df.shape
# Out:
# (10127, 23)

# %%
# Informations on the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %% [markdown]
# The dataset contains 10127 bank customers data, comprising both numerical and categorical values.
#
# ---

# %% [markdown]
# Statistical Summary:

# %%
df.describe().T # T - transpose matrix (row to col, col to rows)
# Out:
#                                                       count          mean  \
# CLIENTNUM                                           10127.0  7.391776e+08
# Customer_Age                                        10127.0  4.632596e+01
# Dependent_count                                     10127.0  2.346203e+00
# Months_on_book                                      10127.0  3.592841e+01
# Total_Relationship_Count                            10127.0  3.812580e+00
# Months_Inactive_12_mon                              10127.0  2.341167e+00
# Contacts_Count_12_mon                               10127.0  2.455317e+00
# Credit_Limit                                        10127.0  8.631954e+03
# Total_Revolving_Bal                                 10127.0  1.162814e+03
# Avg_Open_To_Buy                                     10127.0  7.469140e+03
# Total_Amt_Chng_Q4_Q1                                10127.0  7.599407e-01
# Total_Trans_Amt                                     10127.0  4.404086e+03
# ...

# %%
df.describe(include='object')
# Out:
#            Attrition_Flag Gender Education_Level Marital_Status  \
# count               10127  10127           10127          10127
# unique                  2      2               7              4
# top     Existing Customer      F        Graduate        Married
# freq                 8500   5358            3128           4687
#
#        Income_Category Card_Category
# count            10127         10127
# unique               6             4
# top     Less than $40K          Blue
# freq              3561          9436

# %% [markdown]
# ### Data Cleaning and Transformation

# %% [markdown]
# Removing unnecessary columns:

# %%
cols = [
    'CLIENTNUM', 'Education_Level', 'Marital_Status', 'Avg_Open_To_Buy', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'
]

for col in cols:
    df.drop([col], axis=1, inplace=True)

# %% [markdown]
# ##### Handling Missing Values

# %%
df.isna().sum()
# Out:
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %% [markdown]
# Duplicated values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##### Outlier Detection

# %%
# Checking the min, mean, median, max values of numerical columns
num_cols = df.select_dtypes(include=['number']).columns
summary = pd.DataFrame({
    'Min': df[num_cols].min(),
    'Mean': df[num_cols].mean(),
    'Median': df[num_cols].median(),
    'Max': df[num_cols].max()
})

summary = summary.applymap(lambda x: f"{x:.1f}")
summary
# Out:
#                              Min    Mean  Median      Max
# Customer_Age                26.0    46.3    46.0     73.0
# Dependent_count              0.0     2.3     2.0      5.0
# Months_on_book              13.0    35.9    36.0     56.0
# Total_Relationship_Count     1.0     3.8     4.0      6.0
# Months_Inactive_12_mon       0.0     2.3     2.0      6.0
# Contacts_Count_12_mon        0.0     2.5     2.0      6.0
# Credit_Limit              1438.3  8632.0  4549.0  34516.0
# Total_Revolving_Bal          0.0  1162.8  1276.0   2517.0
# Total_Amt_Chng_Q4_Q1         0.0     0.8     0.7      3.4
# Total_Trans_Amt            510.0  4404.1  3899.0  18484.0
# Total_Trans_Ct              10.0    64.9    67.0    139.0
# Total_Ct_Chng_Q4_Q1          0.0     0.7     0.7      3.7
# Avg_Utilization_Ratio        0.0     0.3     0.2      1.0

# %%
# Displaying box plot of all extreme outliers seen above
out_cols = ['Credit_Limit', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt', 'Total_Ct_Chng_Q4_Q1']
for col in out_cols:
    plt.figure(figsize=[10,1])
    sns.boxplot(x=df[col])
    plt.show()

# %% [markdown]
# ##### Feature Engineering:

# %% [markdown]
# 1. Transaction Frequency

# %%
# Creating new feature for getting the transaction frequency of the customer
df['Avg_Transactions_per_Month'] = df['Total_Trans_Ct'] / df['Months_on_book']
df.sample()
# Out:
#         Attrition_Flag  Customer_Age Gender  Dependent_count Income_Category  \
# 155  Existing Customer            42      F                5     $40K - $60K
#
#     Card_Category  Months_on_book  Total_Relationship_Count  \
# 155          Blue              36                         3
#
#      Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# 155                       3                      3        2038.0
#
#      Total_Revolving_Bal  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  \
# 155                    0                 0.786             1238
#
#      Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 155              28                 0.75                    0.0
#
#      Avg_Transactions_per_Month
# 155                    0.777778

# %% [markdown]
# 2. Inactivity Ratio:

# %%
# Creating new feature for getting the inactivity of the customer
df['Inactivity_ratio'] = df['Months_Inactive_12_mon'] / 12
df.sample()
# Out:
#         Attrition_Flag  Customer_Age Gender  Dependent_count Income_Category  \
# 736  Existing Customer            42      F                4         Unknown
#
#     Card_Category  Months_on_book  Total_Relationship_Count  \
# 736          Blue              36                         5
#
#      Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# 736                       3                      2       17536.0
#
#      Total_Revolving_Bal  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  \
# 736                 1525                 0.859             1411
#
#      Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 736              28                0.474                  0.087
#
#      Avg_Transactions_per_Month  Inactivity_ratio
# 736                    0.777778              0.25

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
df.describe().T
# Out:
#                               count         mean          std          min  \
# Customer_Age                10127.0    46.325960     8.016814    26.000000
# Dependent_count             10127.0     2.346203     1.298908     0.000000
# Months_on_book              10127.0    35.928409     7.986416    13.000000
# Total_Relationship_Count    10127.0     3.812580     1.554408     1.000000
# Months_Inactive_12_mon      10127.0     2.341167     1.010622     0.000000
# Contacts_Count_12_mon       10127.0     2.455317     1.106225     0.000000
# Credit_Limit                10127.0  8631.953698  9088.776650  1438.300000
# Total_Revolving_Bal         10127.0  1162.814061   814.987335     0.000000
# Total_Amt_Chng_Q4_Q1        10127.0     0.759941     0.219207     0.000000
# Total_Trans_Amt             10127.0  4404.086304  3397.129254   510.000000
# Total_Trans_Ct              10127.0    64.858695    23.472570    10.000000
# ...

# %%
# Churn Distribution - countplot of attribution of customer (existing or not)
plt.figure(figsize=(5,5))
sns.countplot(data=df, x='Attrition_Flag', palette='Set2')
plt.title('Customer Churn Distribution')
plt.show()

# %%
df['Attrition_Flag'].value_counts(normalize=True)*100
# Out:
# Attrition_Flag
# Existing Customer    83.934038
# Attrited Customer    16.065962
# Name: proportion, dtype: float64

# %%
for col in ['Gender','Income_Category','Card_Category']:

    plt.figure(figsize=(4,4))

    sns.countplot(
        y=col,
        data=df,
        order=df[col].value_counts().index
    )

    plt.show()

# %%
# Churn vs Income Category

income_churn = pd.crosstab(df['Income_Category'], df['Attrition_Flag'], normalize='index') * 100 ## percentage of customer in each income category
print(income_churn)

plt.figure(figsize=(8,5))
sns.barplot(income_churn['Attrited Customer'])
plt.title('Churn vs Income Category')
# Out:
# Attrition_Flag   Attrited Customer  Existing Customer
# Income_Category
# $120K +                  17.331499          82.668501
# $40K - $60K              15.139665          84.860335
# $60K - $80K              13.480742          86.519258
# $80K - $120K             15.765472          84.234528
# Less than $40K           17.186184          82.813816
# Unknown                  16.816547          83.183453
# Text(0.5, 1.0, 'Churn vs Income Category')

# %%
# Churn vs Card Category

card_churn = pd.crosstab(df['Card_Category'], df['Attrition_Flag'], normalize='index') * 100   # percentage of customer in each income category
print(card_churn)

plt.figure(figsize=(8,5))
sns.barplot(card_churn['Attrited Customer'])
plt.title('Churn vs Card Category')
# Out:
# Attrition_Flag  Attrited Customer  Existing Customer
# Card_Category
# Blue                    16.097923          83.902077
# Gold                    18.103448          81.896552
# Platinum                25.000000          75.000000
# Silver                  14.774775          85.225225
# Text(0.5, 1.0, 'Churn vs Card Category')

# %%
# Churn vs Total Transactions counts
sns.boxplot(df, x='Attrition_Flag', y='Total_Trans_Ct')
plt.title('Churn vs Total Transactions counts')
plt.show()

# %%
# Churn vs Total Transactions amount
sns.boxplot(df, x='Attrition_Flag', y='Total_Trans_Amt')
plt.title('Churn vs Total Transactions amounts')
plt.show()

# %%
# Churn vs Inactivity ratio
sns.boxplot(df, x='Attrition_Flag', y='Months_Inactive_12_mon')
plt.title('Churn vs Months Inactive')
plt.show()

# %%
# Churn vs Relatonship count 
sns.boxplot(df, x='Attrition_Flag', y='Total_Relationship_Count')
plt.title('Churn vs Relationship Count with Bank')
plt.show()

# %%
# Churn vs Average Card utilization 
sns.boxplot(df, x='Attrition_Flag', y='Avg_Utilization_Ratio')
plt.title('Churn vs Average Card Utilization')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df[num_cols].corr(), cmap='coolwarm', annot=True)
plt.title('Correlation Matrix')
plt.show()

# %%
sample_df = df.sample(n=2000, random_state=42)

cols = [
    'Customer_Age',
    'Credit_Limit',
    'Total_Trans_Amt',
    'Total_Trans_Ct',
    'Avg_Utilization_Ratio',
    'Attrition_Flag'
]

sns.pairplot(sample_df[cols], hue='Attrition_Flag')
plt.show()
